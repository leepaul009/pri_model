# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
np.set_printoptions(suppress=True)
pd.set_option('display.max_columns', 100)

data_dir = '../dataset/pwm_data/pwm/'
sub_dir = 'protein_3087'
data_file = 'pssm_hmm.txt'
data_file = os.path.join(data_dir,sub_dir, data_file)

madf = pd.read_csv(data_file, sep='\t', low_memory=False)
madf
# Out:
#    seq   hmm_A   hmm_C   hmm_D   hmm_E   hmm_F   hmm_G   hmm_H   hmm_I  \
# 0    M  0.9999  0.9999  0.9999  0.9999  0.1677  0.9999  0.9999  0.9999
# 1    Y  0.3791  0.9999  0.3940  0.3155  0.7178  0.4387  0.6849  0.6373
# 2    T  0.3429  0.7985  0.5254  0.5020  0.6067  0.4417  0.6128  0.3347
# 3    N  0.4329  0.7851  0.3799  0.3956  0.5894  0.3952  0.6326  0.8326
# 4    S  0.2102  0.9999  0.5318  0.3793  0.9999  0.2017  0.8383  0.9999
# ..  ..     ...     ...     ...     ...     ...     ...     ...     ...
# 69   S  0.3613  0.7403  0.9999  0.9999  0.9999  0.7499  0.9999  0.7020
# 70   E  0.9999  0.9999  0.2235  0.1697  0.7749  0.1541  0.9999  0.9999
# 71   G  0.3320  0.9999  0.3294  0.2339  0.9999  0.3579  0.9999  0.5567
# 72   K  0.5481  0.9999  0.3078  0.2662  0.9999  0.4437  0.9999  0.9999
# 73   K  0.5625  0.9999  0.3870  0.2045  0.9999  0.3830  0.5603  0.9999
#
#      hmm_K   hmm_L   hmm_M   hmm_N   hmm_P   hmm_Q   hmm_R   hmm_S   hmm_T  \
# ...

# %%
data_dir = '../dataset/pwm_data/pwm/'
sub_dir = 'protein_3087'
data_file = 'protein.pssm'
data_file = os.path.join(data_dir,sub_dir, data_file)

madf = pd.read_table(data_file)
madf
# Out:
#    Last position-specific scoring matrix computed, weighted observed percentages rounded down, information per position, and relative weight of gapless real matches to pseudocounts
# 0               A   R   N   D   C   Q   E   G   H ...
# 1       1 M    -2  -3  -4  -5  -3  -2  -4  -4  -3 ...
# 2       2 Y     1  -1   0   2  -3   0   1  -2   0 ...
# 3       3 T     0  -1   2   1   1   1   0  -2  -1 ...
# 4       4 N    -1  -1   3   0  -2   3   1   1   0 ...
# ..                                                ...
# 75                                   K         Lambda
# 76             Standard Ungapped    0.1349     0.3182
# 77             Standard Gapped      0.0576     0.2670
# 78             PSI Ungapped         0.1880     0.3167
# 79             PSI Gapped           0.0576     0.2670
#
# [80 rows x 1 columns]

# %%
pwm_embeding_dims_by_type = {'hmm': 30, 'pssm': 20, 'psfm': 20}

pwm_type = 'hmm'
pwm_type in list(pwm_embeding_dims_by_type.keys())
# Out:
# False

# %%
np.sum([12,22])
# Out:
# 34
